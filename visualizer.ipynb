# %%
from agent import *
from kaggle_environments import make
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True, "height":12, "width":12}, debug=True)
steps = env.run([agent, agent])
# Out:
# [WARN] (match_kxEYU877sOjR) - Agent 1 tried to move unit u_2 onto opponent CityTile; turn 1; cmd: m u_2 w
# [WARN] (match_kxEYU877sOjR) - Agent 1 tried to move unit u_2 off map; turn 2; cmd: m u_2 s
# [WARN] (match_kxEYU877sOjR) - Agent 1 tried to build CityTile on existing CityTile; turn 3; cmd: bcity u_2
# [WARN] (match_kxEYU877sOjR) - turn 6; Unit u_2 collided when trying to move w to (5, 10)
# [WARN] (match_kxEYU877sOjR) - Agent 0 tried to build unit on tile (5, 11) but unit cap reached. Build more CityTiles!; turn 11; cmd: bw 5 11
# [WARN] (match_kxEYU877sOjR) - Agent 1 tried to build CityTile on non-empty resource tile; turn 11; cmd: bcity u_2
# [WARN] (match_kxEYU877sOjR) - Agent 1 tried to build unit on tile (6, 11) but unit cap reached. Build more CityTiles!; turn 11; cmd: bw 6 11
# [WARN] (match_kxEYU877sOjR) - Agent 0 tried to build unit on tile (5, 11) but unit cap reached. Build more CityTiles!; turn 12; cmd: bw 5 11
# ...

# %%
env.render(mode="ipython", width=1000, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;683c75b4-4af3-11ec-ae27-0242ac110002&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 562124210,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;height&quot;: 12,
#       &quot;width&quot;: 12,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;
#     },
#     &quot;specification&quot;: {
# ...
